# %%
class Ses():
    def __init__(self, baslik):
        self.baslik = baslik 
    def oynat(self):
        print(f"Ses Çalmaya Başladı: {self.baslik}")
    def duraklat(self):
        print(f"Ses Duraklatıldı: {self.baslik}")

class Sarki(Ses):
    def __init__(self, sanatci,album,sure):
        super().__init__(baslik)
        self.sanatci = sanatci
        self.album = album

class Podcast(Ses):
    def __init__(self, sunucu, bolum_no, yayinci):
        super().__init__(baslik)
        self.sunucu = sunucu
        self.bolum_no = bolum_no

        
class SesliKitap(Ses):
    def __init__(self, yazar, anlatici, bolum):
        super().__init__(baslik)
        self.yazar = yazar
        self.anlatici = anlatici
